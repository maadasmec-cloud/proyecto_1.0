# %% [markdown]
# <a href="https://colab.research.google.com/github/maadasmec-cloud/proyecto_1.0/blob/main/ejercicio%2005_01_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nombre=input("Ingresa tu nombre:")
while True:
  try:
   edad=int(input("ingrese edad:"))
   break
  except ValueError:
    print("Por favor ingrese edad:")
if edad>=18:
  print(f"{nombre} es mayor de edad")
else:
  print(f"{nombre} es menor de edad")

print("fin.")
# Out:
# Ingresa tu nombre:marco
# ingrese edad:d
# Por favor ingrese edad:
# ingrese edad:o
# Por favor ingrese edad:
# ingrese edad:30
# marco es mayor de edad
# fin.
